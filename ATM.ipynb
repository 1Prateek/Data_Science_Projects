# %% [markdown]
# # DOCUMENTATION

# %% [markdown]
# Idea Of The Project(ATM Machine):
#
#     The Idea is to implememnt an ATM which creates an Account by asking Name and desired Account Number(account balance if required) then asks the user if they want to continue the transaction. Further it asks for a Pin which is by default set to 1111

# %% [markdown]
# On further continuing the transaction it calls the Transaction Function which displays the options in the ATM

# %% [markdown]
# THE TRANSACTION FUNCTION:
#
#     The transaction function Disaplay 6 option and on returning from the transaction it dispalys the receipt of the transaction and greets the user.
#
# OUTPUT :
#
# ![menu.png](attachment:menu.png)

# %% [markdown]
# 1. THE ACCOUNT DETAILS FUNCTION:
#
#          This Funtion prints the account holder's name , Account Number and Account Balance
#
#    OUTPUT:
#
#    ![Account%20_detail.png](attachment:Account%20_detail.png)

# %% [markdown]
# 2. ACCOUNT BALANCE FUNCTION
#
#         This function prints the current available balance of the account . The account balance attribute is made private in the constructor method as to not accesed by anyone outside the class.
#
#   OUTPUT:
#
#   ![Accounr_balance.png](attachment:Accounr_balance.png)

# %% [markdown]
# 3. CREDIT / DEPOSIT FUNCTION:
#
#         This function asks user for an input amount to be credited and add the credited amount to account balance and prints the updated account balance.
#
#    OUTPUT:
#
# ![credit.png](attachment:credit.png)

# %% [markdown]
# 4. WITHDRAW / DEBIT FUNCTION
#
#         This functions ask the user for a amount to be debited and subtracts the amount from the account balance and prints the updated account balance and if the inputed amount is greater than the account balance then ask the user to try a lesser value than before.
#
#    OUTPUT:
#
#    ![debit.png](attachment:debit.png)

# %% [markdown]
# 5. TRANSFER FUND:
#
#         This function asks user to input an account number in which the money is to be transfered and shows error if the inputed account number is not of 10 digit. Then asks the amount to be transfered from the account and ask the PIN to maintain the security of the account and any of the input is wrong then shows the error message.
#
#    OUTPUT:
#
#     ![transfer-2.png](attachment:transfer-2.png)

# %% [markdown]
# 6. EXIT
#
#         This print the receipt of the transaction and ask the user at the end if they want to continue the transaction , if not then greets them and program ends.
#
#    OUTPUT:
#
#    ![exit.png](attachment:exit.png)

# %%
import random

class ATM: # Defining the Class ATM 

    def __init__(self, name, account_no, account_balance=0):  # Initialization the Constructor.
        self.name = name                                      # Sets the Account holder name.
        self.account_no = account_no                          # Sets the Account Holder Account Number.
        self.__account_balance = account_balance              # Sets the Account Balance.
        self.pin = 1111                                       # Sets the ATM pin as default to 1111.

    def print_account_details(self):                          # This Function Prints the Account Details.
        print("\n----------ACCOUNT DETAIL----------")
        print(f"Account Holder: {self.name.upper()}")
        print(f"Account Number: {self.account_no}")
        print(f"Available balance: {self.__account_balance}\n")

    def get_account_balance(self):                            # It is the getter function for Account Balance.
        return self.__account_balance

    def credit(self, amount):                                 # This Credit function updates the Account balance when receive the money.
        self.__account_balance = self.__account_balance+amount
        print("Current account balance: ", self.__account_balance)

    def debit(self, amount):                                  # This Debit function updates the Account Balance when mpney is deducted and shows insuccesful transaction if inappropriate transaction is made.
        if amount > self.__account_balance:
            print("\n---Insufficient Fund---\n")
            print(f"Your balance is Nu.{self.__account_balance} only.")
            print("Try with lesser amount than balance.")
        else:
            self.__account_balance = self.__account_balance-amount
            print(f"{amount} withdrawal successful!")
            print("Current account balance: Nu.", self.__account_balance)

    def check_account_balance(self):                          # Prints the Account balance
        print(f"Available balance: {self.__account_balance}\n")\
    
    def Transfer_Fund(self):                                  # Transfer funds to provided account number and ask for pin before transaction
        input_account=str(int(input("Enter Receiver's 10 digit Account Number: ")))
        if len(input_account)==10:
            input_amount=int(input("Enter the amount to Transfer: "))
            input_pin=int(input("Enter your pin: "))
            if input_pin==self.pin:
                if input_amount<=self.__account_balance:
                    print("-"*50)
                    print("** Transfer Successful **")
                    self.__account_balance-=input_amount
                    print(f"Transferred to Account - {input_account}")
                    print(f"Transferred Amount - {input_amount}")
                    print(f"Available Balance - {self.__account_balance}")
                    print("-"*50)
                else:
                    print("-"*50)
                    print("** Withdrawl Unsuccessful ** \n   --> Insufficient Balance ")
                    print("-"*50)
            else:
                print("-"*50)
                print("** Wrong Pin Enterd ** \n   --> Enter valid 4 digit pin ")
                print("-"*50)
        else:
            print("-"*50)
            print("** Invalid Receiver's Account Number **\n   --> Enter valid 10 digit Receiver's Account Number ")
            print("-"*50)

    def transaction(self):                                    # This is the menu Function which prints the menu and prints the receipt at the end
        print("""
            TRANSACTION 
        *********************
            Menu:
            1. Account Detail
            2. Check Balance
            3. Deposit
            4. Withdraw
            5. Transfer Fund
            6. Exit
        *********************
        """)

        while True:
            try:
                option = int(input("Enter 1, 2, 3, 4 ,5 or 6:"))
            except:
                print("Error: Enter 1, 2, 3, 4, 5 or 6 only!\n")
                continue
            else:
                if option == 1:
                    atm.print_account_details()
                elif option == 2:
                    atm.check_account_balance()
                elif option == 3:
                    amount = int(input("How much you want to deposit(Nu.):"))
                    atm.credit(amount)
                elif option == 4:
                    amount = int(input("How much you want to withdraw(Nu.):"))
                    atm.debit(amount)
                elif option == 5:
                    atm.Transfer_Fund()
                elif option == 6:
                    print(f"""
                printing receipt..............
          ******************************************
              Transaction is now complete.                         
              Transaction number: {random.randint(10000, 1000000)} 
              Account holder: {self.name.upper()}                  
              Account number: {self.account_no}                
              Available balance: Nu.{self.__account_balance}                    
 
              Thanks for choosing us as your bank                  
          ******************************************
          """)
                    return


# Driver Code for the program
                
print("*******WELCOME TO BANK OF DSAT*******")
print("___________________________________________________________\n")
print("----------ACCOUNT CREATION----------")
name = input("Enter your name: ")
account_number = input("Enter your account number: ")
print("Congratulations! Account created successfully......\n")

atm = ATM(name, account_number)                              # Initialization of the Object

while True:                                                  # Asking to continue the transaction
    trans = input("Do you want to do any transaction?(y/n):")
    if trans == "y":
        x = int(input("Enter your pin: "))
        if x == atm.pin:
            atm.transaction()
        else:
            print("Invalid Pin ")
            break
    elif trans == "n":
        print("""
    -------------------------------------
   | Thanks for choosing us as your bank |
   | Visit us again!                     |
    -------------------------------------
        """)
        break
    else:
        print("Wrong command!  Enter 'y' for yes and 'n' for NO.\n")
# Out:
# *******WELCOME TO BANK OF DSAT*******
# ___________________________________________________________
#
# ----------ACCOUNT CREATION----------
# Enter your name: Prateek
# Enter your account number: 123456789
# Congratulations! Account created successfully......
#
# Do you want to do any transaction?(y/n):y
# Enter your pin: 1111
#
#             TRANSACTION
#         *********************
#             Menu:
#             1. Account Detail
#             2. Check Balance
#             3. Deposit
#             4. Withdraw
#             5. Transfer Fund
#             6. Exit
#         *********************
#
# Enter 1, 2, 3, 4 ,5 or 6:1
#
# ----------ACCOUNT DETAIL----------
# Account Holder: PRATEEK
# Account Number: 123456789
# Available balance: 0
#
# Enter 1, 2, 3, 4 ,5 or 6:2
# Available balance: 0
#
# Enter 1, 2, 3, 4 ,5 or 6:3
# How much you want to deposit(Nu.):50000
# Current account balance:  50000
# Enter 1, 2, 3, 4 ,5 or 6:4
# How much you want to withdraw(Nu.):1000
# ...
